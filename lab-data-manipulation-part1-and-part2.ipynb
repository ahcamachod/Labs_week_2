# %% [markdown]
# # Lab-Data-Manipulation (PART-1)

# %%
import pandas as pd
import os

# %% [markdown]
# # Context
#
# For this lab you'll use a dataset for UFO observations. The objective is to exercise the manipulation of a dataframe, so we'll use the tools we've learned about `reading`, `renaming`, `selecting specific columns`, `filtering based on conditions` and `merging` dataframes to try to better understand our dataset and store an enriched version of our dataset at the end.
#
# Good Luck.

# %% [markdown]
# variable	|class|	description
# ------------|-----|-------------
# date_time	|datetime (mdy h:m)	| Date time sighting occurred
# city_area	|character	        | City or area of sighting
# state	    |character          |	state/region of sighting
# country	    |character          |	Country of sighting
# ufo_shape	|character          |	UFO Shape
# encounter_length	|double     |	Encounter length in seconds
# described_encounter_length	|character |	Encounter length as described (eg 1 hour, etc)
# description	|character          |	Description of encounter
# date_documented	|character      |	Date documented
# latitude	|double             |	Latitude
# longitude	|double             |	Longitude

# %% [markdown]
# ## Read the dataset and store it in a dataframe called `ufo`
#
# Pay attention at the file separator.

# %%
pwd
# Out:
# 'C:\\Users\\Alvaro Camacho\\Desktop\\Ironhack\\Week 2\\week2_day3'

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'asset-v1_IRONHACK+DAFT+202002_SAO+type@asset+block@data-manipulation-part1.ipynb',
#  'asset-v1_IRONHACK+DAFT+202002_SAO+type@asset+block@data-manipulation-part2.ipynb',
#  'Data Manipulation 1.ipynb',
#  'Data Manipulation 2.ipynb',
#  'df.csv',
#  'lab-data-manipulation-part1-and-part2.ipynb',
#  'ufo.csv']

# %%
ufo = pd.read_csv('C:\\Users\\Alvaro Camacho\\Desktop\\Ironhack\\Week 2\\week2_day3/ufo.csv', sep=';')
ufo
# Out:
#        Unnamed: 0        date  year  month  day         date_time  \
# 0               0  1949-10-10  1949     10   10  10/10/1949 20:30
# 1               1  1949-10-10  1949     10   10  10/10/1949 21:00
# 2               2  1955-10-10  1955     10   10  10/10/1955 17:00
# 3               3  1956-10-10  1956     10   10  10/10/1956 21:00
# 4               4  1960-10-10  1960     10   10  10/10/1960 20:00
# ...           ...         ...   ...    ...  ...               ...
# 80327       80327  2013-09-09  2013      9    9    9/9/2013 21:15
# 80328       80328  2013-09-09  2013      9    9    9/9/2013 22:00
# 80329       80329  2013-09-09  2013      9    9    9/9/2013 22:00
# 80330       80330  2013-09-09  2013      9    9    9/9/2013 22:20
# 80331       80331  2013-09-09  2013      9    9    9/9/2013 23:00
#
#                   city_area state country ufo_shape  encounter_length  \
# 0                san marcos    tx      us  cylinder            2700.0
# 1              lackland afb    tx     NaN     light            7200.0
# 2      chester (uk/england)   NaN      gb    circle              20.0
# 3                      edna    tx      us    circle              20.0
# 4                   kaneohe    hi      us     light             900.0
# ...                     ...   ...     ...       ...               ...
# 80327             nashville    tn      us     light             600.0
# 80328                 boise    id      us    circle            1200.0
# 80329                  napa    ca      us     other            1200.0
# 80330                vienna    va      us    circle               5.0
# 80331                edmond    ok      us     cigar            1020.0
#
#       described_encounter_length  \
# 0                     45 minutes
# 1                        1-2 hrs
# 2                     20 seconds
# 3                       1/2 hour
# 4                     15 minutes
# ...                          ...
# 80327                 10 minutes
# 80328                 20 minutes
# 80329                       hour
# 80330                  5 seconds
# 80331                 17 minutes
#
#                                              description date_documented  \
# 0      This event took place in early fall around 194...       4/27/2004
# 1      1949 Lackland AFB&#44 TX.  Lights racing acros...      12/16/2005
# 2      Green/Orange circular disc over Chester&#44 En...       1/21/2008
# 3      My older brother and twin sister were leaving ...       1/17/2004
# 4      AS a Marine 1st Lt. flying an FJ4B fighter/att...       1/22/2004
# ...                                                  ...             ...
# 80327  Round from the distance/slowly changing colors...       9/30/2013
# 80328  Boise&#44 ID&#44 spherical&#44 20 min&#44 10 r...       9/30/2013
# 80329                                       Napa UFO&#44       9/30/2013
# 80330  Saw a five gold lit cicular craft moving fastl...       9/30/2013
# 80331  2 witnesses 2  miles apart&#44 Red &amp; White...       9/30/2013
#
#         latitude   longitude
# 0      29.883056  -97.941111
# 1      29.384210  -98.581082
# 2      53.200000   -2.916667
# 3      28.978333  -96.645833
# 4      21.418056 -157.803611
# ...          ...         ...
# 80327  36.165833  -86.784444
# 80328  43.613611 -116.202500
# 80329  38.297222 -122.284444
# 80330  38.901111  -77.265556
# 80331  35.652778  -97.477778
#
# [80332 rows x 16 columns]

# %% [markdown]
# ## Check the first 6 columns of the dataframe

# %%
ufo.iloc[:,:6]
# Out:
#        Unnamed: 0        date  year  month  day         date_time
# 0               0  1949-10-10  1949     10   10  10/10/1949 20:30
# 1               1  1949-10-10  1949     10   10  10/10/1949 21:00
# 2               2  1955-10-10  1955     10   10  10/10/1955 17:00
# 3               3  1956-10-10  1956     10   10  10/10/1956 21:00
# 4               4  1960-10-10  1960     10   10  10/10/1960 20:00
# ...           ...         ...   ...    ...  ...               ...
# 80327       80327  2013-09-09  2013      9    9    9/9/2013 21:15
# 80328       80328  2013-09-09  2013      9    9    9/9/2013 22:00
# 80329       80329  2013-09-09  2013      9    9    9/9/2013 22:00
# 80330       80330  2013-09-09  2013      9    9    9/9/2013 22:20
# 80331       80331  2013-09-09  2013      9    9    9/9/2013 23:00
#
# [80332 rows x 6 columns]

# %% [markdown]
# ## Check the shape of your dataframe to see how many rows and columns it has

# %%
ufo.shape
# Out:
# (80332, 16)

# %% [markdown]
# ## Bring the date information to the beginning of the dataframe
#
# If you check the dataframe columns, there are some information of the date at the end of the dataframe. For this task, you should reorder the columns in a way that the first few columns all show the date information.
#
# *Hint: Use the ufo.columns to see all the column names you have.

# %%
ufo.columns
# Out:
# Index(['Unnamed: 0', 'date', 'year', 'month', 'day', 'date_time', 'city_area',
#        'state', 'country', 'ufo_shape', 'encounter_length',
#        'described_encounter_length', 'description', 'date_documented',
#        'latitude', 'longitude'],
#       dtype='object')

# %%
ufo = ufo[['date','Unnamed: 0', 'year', 'month', 'day', 'date_time', 'city_area',
       'state', 'country', 'ufo_shape', 'encounter_length',
       'described_encounter_length', 'description', 'date_documented',
       'latitude', 'longitude']]

# %% [markdown]
# ## Just check if you did it the right way. Take a look at the head of the dataframe again and see if the `ufo` dataframe now is reordered.

# %%
ufo.head()
# Out:
#          date  Unnamed: 0  year  month  day         date_time  \
# 0  1949-10-10           0  1949     10   10  10/10/1949 20:30
# 1  1949-10-10           1  1949     10   10  10/10/1949 21:00
# 2  1955-10-10           2  1955     10   10  10/10/1955 17:00
# 3  1956-10-10           3  1956     10   10  10/10/1956 21:00
# 4  1960-10-10           4  1960     10   10  10/10/1960 20:00
#
#               city_area state country ufo_shape  encounter_length  \
# 0            san marcos    tx      us  cylinder            2700.0
# 1          lackland afb    tx     NaN     light            7200.0
# 2  chester (uk/england)   NaN      gb    circle              20.0
# 3                  edna    tx      us    circle              20.0
# 4               kaneohe    hi      us     light             900.0
#
#   described_encounter_length  \
# 0                 45 minutes
# 1                    1-2 hrs
# 2                 20 seconds
# 3                   1/2 hour
# 4                 15 minutes
#
#                                          description date_documented  \
# 0  This event took place in early fall around 194...       4/27/2004
# 1  1949 Lackland AFB&#44 TX.  Lights racing acros...      12/16/2005
# 2  Green/Orange circular disc over Chester&#44 En...       1/21/2008
# 3  My older brother and twin sister were leaving ...       1/17/2004
# 4  AS a Marine 1st Lt. flying an FJ4B fighter/att...       1/22/2004
#
#     latitude   longitude
# 0  29.883056  -97.941111
# 1  29.384210  -98.581082
# 2  53.200000   -2.916667
# 3  28.978333  -96.645833
# 4  21.418056 -157.803611

# %% [markdown]
# ## Select a piece of your dataframe. Create a new dataframe called `ufo_vars` and select only the following columns of the `ufo` dataframe.
#
# `year`, `month`, `state`, `country`, `ufo_shape`, `encounter_length`

# %%
ufo_vars = ufo.loc[:,['year','month','state','ufo_shape','encounter_length']]
ufo_vars
# Out:
#        year  month state ufo_shape  encounter_length
# 0      1949     10    tx  cylinder            2700.0
# 1      1949     10    tx     light            7200.0
# 2      1955     10   NaN    circle              20.0
# 3      1956     10    tx    circle              20.0
# 4      1960     10    hi     light             900.0
# ...     ...    ...   ...       ...               ...
# 80327  2013      9    tn     light             600.0
# 80328  2013      9    id    circle            1200.0
# 80329  2013      9    ca     other            1200.0
# 80330  2013      9    va    circle               5.0
# 80331  2013      9    ok     cigar            1020.0
#
# [80332 rows x 5 columns]

# %% [markdown]
# Perform a *.head()* on your result to check if you did it right.

# %%
ufo_vars.head()
# Out:
#    year  month state ufo_shape  encounter_length
# 0  1949     10    tx  cylinder            2700.0
# 1  1949     10    tx     light            7200.0
# 2  1955     10   NaN    circle              20.0
# 3  1956     10    tx    circle              20.0
# 4  1960     10    hi     light             900.0

# %% [markdown]
# ## Rename the variable `encounter_length` to `encounter_seconds`. Keep using the `ufo_vars` dataset for the following tasks, unless specifically specified.
#
# Again, check your results to check if you did it right.

# %%
ufo_vars = ufo_vars.rename({'encounter_length':'encounter_seconds'}, axis=1)
ufo_vars
# Out:
#        year  month state ufo_shape  encounter_seconds
# 0      1949     10    tx  cylinder             2700.0
# 1      1949     10    tx     light             7200.0
# 2      1955     10   NaN    circle               20.0
# 3      1956     10    tx    circle               20.0
# 4      1960     10    hi     light              900.0
# ...     ...    ...   ...       ...                ...
# 80327  2013      9    tn     light              600.0
# 80328  2013      9    id    circle             1200.0
# 80329  2013      9    ca     other             1200.0
# 80330  2013      9    va    circle                5.0
# 80331  2013      9    ok     cigar             1020.0
#
# [80332 rows x 5 columns]

# %% [markdown]
# ## Let's start filtering some records. Create a new dataframe called `ufo_us` and filter the `ufo_vars` dataframe bringing only the results in which the `country` is `"us"`

# %% [markdown]
# ### Use a mask to perform this task
#
# A `mask` is nothing more than a condition. This condition is applied to your whole dataframe (or pandas Series).
# So for example, if you had a pandas Series with a variable called `Age`, you could create a mask for all people whose `Age` is less than 18 years old using the syntax:
#
# `df['Age'] <= 18`
#
# This would return a pandas series containing `True` and `False` values. For each index, you'd get a value of `True` or `False`.
#
# You could save this mask in a variable, for example:
#
# `condition = (df['Age'] <= 18)`
#
# And then you could use that variable `condition` to select only the cases of the dataframe in which the index returned `True` using:
# df[condition].

# %%
mask = ufo['country'] == 'us'
ufo_us = ufo.loc[mask]
ufo_us
# Out:
#              date  Unnamed: 0  year  month  day         date_time   city_area  \
# 0      1949-10-10           0  1949     10   10  10/10/1949 20:30  san marcos
# 3      1956-10-10           3  1956     10   10  10/10/1956 21:00        edna
# 4      1960-10-10           4  1960     10   10  10/10/1960 20:00     kaneohe
# 5      1961-10-10           5  1961     10   10  10/10/1961 19:00     bristol
# 7      1965-10-10           7  1965     10   10  10/10/1965 23:45     norwalk
# ...           ...         ...   ...    ...  ...               ...         ...
# 80327  2013-09-09       80327  2013      9    9    9/9/2013 21:15   nashville
# 80328  2013-09-09       80328  2013      9    9    9/9/2013 22:00       boise
# 80329  2013-09-09       80329  2013      9    9    9/9/2013 22:00        napa
# 80330  2013-09-09       80330  2013      9    9    9/9/2013 22:20      vienna
# 80331  2013-09-09       80331  2013      9    9    9/9/2013 23:00      edmond
#
#       state country ufo_shape  encounter_length described_encounter_length  \
# 0        tx      us  cylinder            2700.0                 45 minutes
# 3        tx      us    circle              20.0                   1/2 hour
# 4        hi      us     light             900.0                 15 minutes
# 5        tn      us    sphere             300.0                  5 minutes
# 7        ct      us      disk            1200.0                 20 minutes
# ...     ...     ...       ...               ...                        ...
# 80327    tn      us     light             600.0                 10 minutes
# 80328    id      us    circle            1200.0                 20 minutes
# 80329    ca      us     other            1200.0                       hour
# 80330    va      us    circle               5.0                  5 seconds
# 80331    ok      us     cigar            1020.0                 17 minutes
#
#                                              description date_documented  \
# 0      This event took place in early fall around 194...       4/27/2004
# 3      My older brother and twin sister were leaving ...       1/17/2004
# 4      AS a Marine 1st Lt. flying an FJ4B fighter/att...       1/22/2004
# 5      My father is now 89 my brother 52 the girl wit...       4/27/2007
# 7      A bright orange color changing to reddish colo...       10/2/1999
# ...                                                  ...             ...
# 80327  Round from the distance/slowly changing colors...       9/30/2013
# 80328  Boise&#44 ID&#44 spherical&#44 20 min&#44 10 r...       9/30/2013
# 80329                                       Napa UFO&#44       9/30/2013
# 80330  Saw a five gold lit cicular craft moving fastl...       9/30/2013
# 80331  2 witnesses 2  miles apart&#44 Red &amp; White...       9/30/2013
#
#         latitude   longitude
# 0      29.883056  -97.941111
# 3      28.978333  -96.645833
# 4      21.418056 -157.803611
# 5      36.595000  -82.188889
# 7      41.117500  -73.408333
# ...          ...         ...
# 80327  36.165833  -86.784444
# 80328  43.613611 -116.202500
# 80329  38.297222 -122.284444
# 80330  38.901111  -77.265556
# 80331  35.652778  -97.477778
#
# [65114 rows x 16 columns]

# %% [markdown]
# ### Use the .query() method to perform the same task
#
# Remember that the .query() method expects a string. That string should contain the variable of your dataframe without quotation marks and the comparison. For example, if you had a variable called `name`, you'd use a syntax like:
#  `df.query('name == "Jack"')`
#
# to bring all observations whose column `name` is exactly equal to `"Jack"` (note that Jack should be within quotation marks because a name is a string in this example).

# %%
ufo.query('country == "us"')
# Out:
#              date  Unnamed: 0  year  month  day         date_time   city_area  \
# 0      1949-10-10           0  1949     10   10  10/10/1949 20:30  san marcos
# 3      1956-10-10           3  1956     10   10  10/10/1956 21:00        edna
# 4      1960-10-10           4  1960     10   10  10/10/1960 20:00     kaneohe
# 5      1961-10-10           5  1961     10   10  10/10/1961 19:00     bristol
# 7      1965-10-10           7  1965     10   10  10/10/1965 23:45     norwalk
# ...           ...         ...   ...    ...  ...               ...         ...
# 80327  2013-09-09       80327  2013      9    9    9/9/2013 21:15   nashville
# 80328  2013-09-09       80328  2013      9    9    9/9/2013 22:00       boise
# 80329  2013-09-09       80329  2013      9    9    9/9/2013 22:00        napa
# 80330  2013-09-09       80330  2013      9    9    9/9/2013 22:20      vienna
# 80331  2013-09-09       80331  2013      9    9    9/9/2013 23:00      edmond
#
#       state country ufo_shape  encounter_length described_encounter_length  \
# 0        tx      us  cylinder            2700.0                 45 minutes
# 3        tx      us    circle              20.0                   1/2 hour
# 4        hi      us     light             900.0                 15 minutes
# 5        tn      us    sphere             300.0                  5 minutes
# 7        ct      us      disk            1200.0                 20 minutes
# ...     ...     ...       ...               ...                        ...
# 80327    tn      us     light             600.0                 10 minutes
# 80328    id      us    circle            1200.0                 20 minutes
# 80329    ca      us     other            1200.0                       hour
# 80330    va      us    circle               5.0                  5 seconds
# 80331    ok      us     cigar            1020.0                 17 minutes
#
#                                              description date_documented  \
# 0      This event took place in early fall around 194...       4/27/2004
# 3      My older brother and twin sister were leaving ...       1/17/2004
# 4      AS a Marine 1st Lt. flying an FJ4B fighter/att...       1/22/2004
# 5      My father is now 89 my brother 52 the girl wit...       4/27/2007
# 7      A bright orange color changing to reddish colo...       10/2/1999
# ...                                                  ...             ...
# 80327  Round from the distance/slowly changing colors...       9/30/2013
# 80328  Boise&#44 ID&#44 spherical&#44 20 min&#44 10 r...       9/30/2013
# 80329                                       Napa UFO&#44       9/30/2013
# 80330  Saw a five gold lit cicular craft moving fastl...       9/30/2013
# 80331  2 witnesses 2  miles apart&#44 Red &amp; White...       9/30/2013
#
#         latitude   longitude
# 0      29.883056  -97.941111
# 3      28.978333  -96.645833
# 4      21.418056 -157.803611
# 5      36.595000  -82.188889
# 7      41.117500  -73.408333
# ...          ...         ...
# 80327  36.165833  -86.784444
# 80328  43.613611 -116.202500
# 80329  38.297222 -122.284444
# 80330  38.901111  -77.265556
# 80331  35.652778  -97.477778
#
# [65114 rows x 16 columns]

# %% [markdown]
# See which one do you prefer the most and keep using it for the exercises that follow

# %% [markdown]
# ## For the `ufo_us` dataframe, select only the cases in which the year is in the first decade (2001-2010). Put that in a variable called `ufo_us_2000`.
#
# Check your results.

# %%
cond1 = ufo['year']>=2001
cond2 = ufo['year']<=2010
ufo_us_2000 = ufo.loc[cond1 & cond2,:]
ufo_us_2000
# Out:
#              date  Unnamed: 0  year  month  day         date_time  \
# 102    2001-10-10         102  2001     10   10  10/10/2001 03:00
# 103    2001-10-10         103  2001     10   10  10/10/2001 04:33
# 104    2001-10-10         104  2001     10   10  10/10/2001 20:10
# 105    2001-10-10         105  2001     10   10  10/10/2001 20:35
# 106    2001-10-10         106  2001     10   10  10/10/2001 21:15
# ...           ...         ...   ...    ...  ...               ...
# 80269  2010-09-09       80269  2010      9    9    9/9/2010 21:30
# 80270  2010-09-09       80270  2010      9    9    9/9/2010 22:00
# 80271  2010-09-09       80271  2010      9    9    9/9/2010 22:00
# 80272  2010-09-09       80272  2010      9    9    9/9/2010 22:00
# 80273  2010-09-09       80273  2010      9    9    9/9/2010 23:19
#
#                         city_area state country  ufo_shape  encounter_length  \
# 102                 rockwell city    ia      us   triangle             240.0
# 103    sydney (nsw&#44 australia)   NaN      au  formation             180.0
# 104            vancouver (canada)    bc      ca      other             300.0
# 105                       hayward    ca      us     circle             120.0
# 106                       ottumwa    ia      us  rectangle             300.0
# ...                           ...   ...     ...        ...               ...
# 80269                    brighton    mi      us   changing             300.0
# 80270                 gainesville    fl      us       oval            2700.0
# 80271                 gainesville    fl      us       oval            7200.0
# 80272                     lemitar    nm      us   fireball             300.0
# 80273                      upland    ca      us     circle             300.0
#
#       described_encounter_length  \
# 102                      4 min.s
# 103                    3 minutes
# 104                   +5 minutes
# 105                       2/min.
# 106                  3-5 minutes
# ...                          ...
# 80269                3-5 minutes
# 80270                     45 min
# 80271                     2+ hrs
# 80272                3 to 5 mins
# 80273                    3-5 min
#
#                                              description date_documented  \
# 102    Large&#44silent&#44slow&#44low to the ground d...        7/1/2002
# 103                                 formation and impact      11/20/2001
# 104    I observed an green object significantly above...       5/12/2011
# 105    FALLING STAR  STOPS  &#39SHOTS OUT  DOZENS OF ...      11/20/2001
# 106    We saw a square object at night&#44  which had...      11/20/2001
# ...                                                  ...             ...
# 80269  Glittery random lights near each other&#44 rea...      11/21/2010
# 80270  2nd night watching the objects&#44 approximate...      11/21/2010
# 80271  Multiple sightings by multiple whitnesses&#44 ...      11/21/2010
# 80272  orange lights in the southeastern sky in New M...      11/21/2010
# 80273  It appeared to be an orange round object movin...      11/21/2010
#
#         latitude   longitude
# 102    42.395278  -94.633611
# 103   -33.861481  151.205475
# 104    49.250000 -123.133333
# 105    37.668889 -122.079722
# 106    41.004167  -92.373611
# ...          ...         ...
# 80269  42.529444  -83.780278
# 80270  29.651389  -82.325000
# 80271  29.651389  -82.325000
# 80272  34.159722 -106.909722
# 80273  34.097500 -117.647500
#
# [40293 rows x 16 columns]

# %% [markdown]
# ## Try to do the same without the intermediate step of creating the `ufo_us` dataframe. That is, try to filter the dataset for the cases in which the country is "us" and the year is (2001-2010)
#
#
#
# *Hint:* You have to make sure all of these conditions are applied simultaneously - using the `and` (or `&`) operator. Try to understand when to use the `and` and the `&` operator.

# %%
ufo.loc[(cond1 & cond2) & mask, :]
# Out:
#              date  Unnamed: 0  year  month  day         date_time  \
# 102    2001-10-10         102  2001     10   10  10/10/2001 03:00
# 105    2001-10-10         105  2001     10   10  10/10/2001 20:35
# 106    2001-10-10         106  2001     10   10  10/10/2001 21:15
# 107    2001-10-10         107  2001     10   10  10/10/2001 21:30
# 108    2001-10-10         108  2001     10   10  10/10/2001 22:00
# ...           ...         ...   ...    ...  ...               ...
# 80269  2010-09-09       80269  2010      9    9    9/9/2010 21:30
# 80270  2010-09-09       80270  2010      9    9    9/9/2010 22:00
# 80271  2010-09-09       80271  2010      9    9    9/9/2010 22:00
# 80272  2010-09-09       80272  2010      9    9    9/9/2010 22:00
# 80273  2010-09-09       80273  2010      9    9    9/9/2010 23:19
#
#            city_area state country  ufo_shape  encounter_length  \
# 102    rockwell city    ia      us   triangle             240.0
# 105          hayward    ca      us     circle             120.0
# 106          ottumwa    ia      us  rectangle             300.0
# 107           fresno    ca      us   changing             900.0
# 108          phoenix    az      us   triangle              60.0
# ...              ...   ...     ...        ...               ...
# 80269       brighton    mi      us   changing             300.0
# 80270    gainesville    fl      us       oval            2700.0
# 80271    gainesville    fl      us       oval            7200.0
# 80272        lemitar    nm      us   fireball             300.0
# 80273         upland    ca      us     circle             300.0
#
#       described_encounter_length  \
# 102                      4 min.s
# 105                       2/min.
# 106                  3-5 minutes
# 107                15 min. apprx
# 108           less then a minute
# ...                          ...
# 80269                3-5 minutes
# 80270                     45 min
# 80271                     2+ hrs
# 80272                3 to 5 mins
# 80273                    3-5 min
#
#                                              description date_documented  \
# 102    Large&#44silent&#44slow&#44low to the ground d...        7/1/2002
# 105    FALLING STAR  STOPS  &#39SHOTS OUT  DOZENS OF ...      11/20/2001
# 106    We saw a square object at night&#44  which had...      11/20/2001
# 107    Objects were sighted driving north on Highway ...      11/20/2001
# 108    Triangle shaped craft spotted flying west to e...      11/20/2001
# ...                                                  ...             ...
# 80269  Glittery random lights near each other&#44 rea...      11/21/2010
# 80270  2nd night watching the objects&#44 approximate...      11/21/2010
# 80271  Multiple sightings by multiple whitnesses&#44 ...      11/21/2010
# 80272  orange lights in the southeastern sky in New M...      11/21/2010
# 80273  It appeared to be an orange round object movin...      11/21/2010
#
#         latitude   longitude
# 102    42.395278  -94.633611
# 105    37.668889 -122.079722
# 106    41.004167  -92.373611
# 107    36.747778 -119.771389
# 108    33.448333 -112.073333
# ...          ...         ...
# 80269  42.529444  -83.780278
# 80270  29.651389  -82.325000
# 80271  29.651389  -82.325000
# 80272  34.159722 -106.909722
# 80273  34.097500 -117.647500
#
# [31910 rows x 16 columns]

# %% [markdown]
# ## BONUS 1:  Compare the number of triangular UFO occurrances (checking the `ufo_shape` variable) in the US from the year 2001 up to 2010 as compared to the years of 1991 up to 2000.
#
# *Hint: you should expect roughly ~3 times more cases for 2001-2010 than 1991-2000.*

# %%
# calculate the dataframe from 2001-2010 here
cond3 = ufo['ufo_shape'] == 'triangle'
ufo.loc[((cond1 & cond2) & mask) & cond3, :]
# Out:
#              date  Unnamed: 0  year  month  day         date_time  \
# 102    2001-10-10         102  2001     10   10  10/10/2001 03:00
# 108    2001-10-10         108  2001     10   10  10/10/2001 22:00
# 109    2001-10-10         109  2001     10   10  10/10/2001 23:00
# 127    2004-10-10         127  2004     10   10  10/10/2004 02:50
# 147    2005-10-10         147  2005     10   10  10/10/2005 20:00
# ...           ...         ...   ...    ...  ...               ...
# 80195  2004-09-09       80195  2004      9    9    9/9/2004 22:00
# 80231  2008-09-09       80231  2008      9    9    9/9/2008 22:00
# 80235  2009-09-09       80235  2009      9    9    9/9/2009 03:38
# 80248  2009-09-09       80248  2009      9    9    9/9/2009 20:45
# 80256  2009-09-09       80256  2009      9    9    9/9/2009 21:40
#
#             city_area state country ufo_shape  encounter_length  \
# 102     rockwell city    ia      us  triangle             240.0
# 108           phoenix    az      us  triangle              60.0
# 109    virginia beach    va      us  triangle              30.0
# 127            mahwah    nj      us  triangle             180.0
# 147           loretto    pa      us  triangle             300.0
# ...               ...   ...     ...       ...               ...
# 80195         corunna    mi      us  triangle             240.0
# 80231     shelbyville    il      us  triangle               7.0
# 80235          denver    co      us  triangle             900.0
# 80248          elkton    or      us  triangle             300.0
# 80256      boyne city    mi      us  triangle             360.0
#
#       described_encounter_length  \
# 102                      4 min.s
# 108           less then a minute
# 109                   30 seconds
# 127                2 - 3 minutes
# 147                    5 minutes
# ...                          ...
# 80195                     4 mins
# 80231                  7 seconds
# 80235                 15 minutes
# 80248                  5 minutes
# 80256                     6 min.
#
#                                              description date_documented  \
# 102    Large&#44silent&#44slow&#44low to the ground d...        7/1/2002
# 108    Triangle shaped craft spotted flying west to e...      11/20/2001
# 109    shaped like a stealth bomber (boomerang like&#...       7/26/2002
# 127    Triangle shaped flying&#44 hovering U.F.O. wit...      12/12/2011
# 147    Dull red flash&#44 Triangular ship&#44 Vocal N...      10/30/2006
# ...                                                  ...             ...
# 80195  Flying Triangle seen over a  field in Michigan...       9/29/2004
# 80231  triangle &#443 huge bright lights&#44 fly over...      10/31/2008
# 80235                      Bright triangle lights in sky      12/12/2009
# 80248  Two triangluar-shaped craft filmed near Elkton...      12/12/2009
# 80256  candy cane shape across sky  followed by trian...      12/12/2009
#
#         latitude   longitude
# 102    42.395278  -94.633611
# 108    33.448333 -112.073333
# 109    36.852778  -75.978333
# 127    41.088611  -74.144167
# 147    40.503056  -78.630556
# ...          ...         ...
# 80195  42.981944  -84.117778
# 80231  39.406389  -88.790000
# 80235  39.739167 -104.984167
# 80248  43.637778 -123.566944
# 80256  45.216667  -85.013889
#
# [3353 rows x 16 columns]

# %%
# calculate the dataframe from 1991-2000 here
cond4 = ufo['year']>=1991
cond5 = ufo['year']<=2000
ufo.loc[((cond4 & cond5) & mask) & cond3, :]
# Out:
#              date  Unnamed: 0  year  month  day         date_time  \
# 50     1991-10-10          50  1991     10   10  10/10/1991 22:00
# 64     1996-10-10          64  1996     10   10  10/10/1996 03:20
# 70     1997-10-10          70  1997     10   10  10/10/1997 20:00
# 78     1998-10-10          78  1998     10   10  10/10/1998 20:30
# 291    1994-10-11         291  1994     10   11  10/11/1994 02:00
# ...           ...         ...   ...    ...  ...               ...
# 79711  2000-09-07       79711  2000      9    7    9/7/2000 20:00
# 79712  2000-09-07       79712  2000      9    7    9/7/2000 20:30
# 79897  1999-09-08       79897  1999      9    8    9/8/1999 21:58
# 79898  1999-09-08       79898  1999      9    8    9/8/1999 22:00
# 80139  2000-09-09       80139  2000      9    9    9/9/2000 21:30
#
#                                                city_area state country  \
# 50                                            harrisburg    pa      us
# 64                                          higginsville    mo      us
# 70                                               bonaire    ga      us
# 78     spokane (about 30 miles sw of&#44i-90&#44 mayb...    wa      us
# 291                                              jackson    nj      us
# ...                                                  ...   ...     ...
# 79711                                           glendale    az      us
# 79712                                           syracuse    ny      us
# 79897                                         bellingham    wa      us
# 79898                                             albany    or      us
# 80139                                          hermitage    pa      us
#
#       ufo_shape  encounter_length described_encounter_length  \
# 50     triangle             600.0                 10 minutes
# 64     triangle               3.0                       3sec
# 70     triangle             300.0                 <5 minutes
# 78     triangle             600.0                 10 minutes
# 291    triangle             300.0                      5mins
# ...         ...               ...                        ...
# 79711  triangle             120.0                  2 minutes
# 79712  triangle             300.0                     5 mins
# 79897  triangle              10.0                 10 seconds
# 79898  triangle              15.0            appox 10-15 sec
# 80139  triangle              15.0               10-15seconds
#
#                                              description date_documented  \
# 50     We observed 3 triangular shaped high speed obj...        5/9/2003
# 64     illuminated triangular craft&#44 flying at hig...       2/16/2000
# 70         Triangular Object Sighted at Very Close Range        2/1/2007
# 78     Dark boomerange object seen for ten minutes ho...        8/5/2001
# 291    triangle UFO in jackson NJ  Countyline 526   o...       1/29/2002
# ...                                                  ...             ...
# 79711  At an intersecton I saw a silent and motionles...        8/5/2001
# 79712  I was on I-90 30&#44 miles west of Syracuse&#4...       9/17/2000
# 79897  At 9:58pm on 9/8/99 I was on the back deck smo...       9/12/1999
# 79898  The craft was flying at approx. 200 feet with ...       9/12/1999
# 80139  On 09/09/2000 I saw an object that had three r...       9/17/2000
#
#         latitude   longitude
# 50     40.273611  -76.884722
# 64     39.072500  -93.716944
# 70     32.543611  -83.596111
# 78     47.658889 -117.425000
# 291    39.776389  -74.862778
# ...          ...         ...
# 79711  33.538611 -112.185278
# 79712  43.048056  -76.147778
# 79897  48.759722 -122.486944
# 79898  44.636667 -123.104722
# 80139  41.233333  -80.448889
#
# [1116 rows x 16 columns]

# %% [raw]
# How many rows does each dataset have?
#
# # 2001-2010 = 3353 rows
# # 1991-2000 = 1116 rows

# %% [markdown]
# ## BONUS 1.1: How many values does each category of `ufo_shape` has.

# %%
x = ufo['ufo_shape']
x.value_counts()
# Out:
# light        16565
# triangle      7865
# circle        7608
# fireball      6208
# other         5649
# unknown       5584
# sphere        5387
# disk          5213
# oval          3733
# formation     2457
# cigar         2057
# changing      1962
# flash         1328
# rectangle     1297
# cylinder      1283
# diamond       1178
# chevron        952
# egg            759
# teardrop       750
# cone           316
# cross          233
# delta            7
# round            2
# crescent         2
# dome             1
# hexagon          1
# pyramid          1
# changed          1
# flare            1
# Name: ufo_shape, dtype: int64

# %% [markdown]
# # Lab-Data-Manipulation (PART-2)

# %% [markdown]
# The second part of this lab consists of grouping and merging results.

# %% [markdown]
# # Grouping up the results.

# %% [markdown]
# ## Let's calculate the average of the encounter for each country.
#
# We should now group the results by the country column to see what is the mean encounter_seconds for each country. Do this using the `groupby` method of your dataframe `ufo_vars`. What is the average of the encounter for the us? And for Canada?
#
# Remember that after grouping by a column, you have to specify a `aggregating function`. If you don't do that, the results of the groupby will only be a `groupby` pandas object. For this case, we want the aggregating function to be the `mean` function and then the results will appear for us.
#
# Also remember that **if you don't** specify the `as_index=False` argument, the variables you use to group are going to become your new indexes.

# %%
ufo_vars = ufo.loc[:,['country','year','month','state','ufo_shape','encounter_length']]
ufo_vars.groupby(by=['country'], as_index=False)[['encounter_length']].mean()
# The mean for US encounter seconds is 5800.19
# The mean for CA encounter seconds is 28859.43
# Out:
#   country  encounter_length
# 0      au       3806.469238
# 1      ca      28859.437007
# 2      de      24255.980952
# 3      gb      66061.321207
# 4      us       5800.192049

# %% [markdown]
# ## Perform the same task, but instead of calculating the mean, count how many occurrances for each country.
#
# For this case, the aggregating function should be the `count` function. Try to understand the results for each column.

# %%
ufo_vars.groupby(by=['country'], as_index=False)[['encounter_length']].count()
# Out:
#   country  encounter_length
# 0      au               538
# 1      ca              3000
# 2      de               105
# 3      gb              1905
# 4      us             65112

# %% [markdown]
# ## Perform the same task, but instead of calculating the mean, use the `.describe()` aggregating function to see the effects.
#
# The describe aggregating function will show you several important statistics for the grouped results, such as `mean`, `median`, `standard deviation`, `count`, `max`, `min`, and so on.
#
# *Hint: If it starts to get difficult to see the results, you can tranpose the resulting dataframe by just putting a `.T` at the end.*

# %%
ufo_vars.groupby(by=['country'], as_index=False)[['encounter_length']].describe()
# Out:
#   encounter_length                                                        \
#              count          mean           std   min   25%    50%    75%
# 0            538.0   3806.469238  5.434101e+04  0.50  30.0  180.0  600.0
# 1           3000.0  28859.437007  1.511732e+06  0.02  20.0  120.0  600.0
# 2            105.0  24255.980952  1.859988e+05  2.00  30.0  180.0  600.0
# 3           1905.0  66061.321207  2.314714e+06  0.30  30.0  180.0  600.0
# 4          65112.0   5800.192049  4.045197e+05  0.01  30.0  180.0  600.0
#
#
#           max
# 0   1209600.0
# 1  82800000.0
# 2   1814400.0
# 3  97836000.0
# 4  66276000.0

# %% [markdown]
# ## Now, let's get deeper in the analysis and group the results not only by country. But by `country` and `year`

# %% [markdown]
# ### Check the values of the mean and count for the `encounter_seconds` variable for each year. Can you see some discrepancy?
#
# *Hint*: If you want, you can use the `ufo_us` dataset just to see the results for the united states. You could also (in a hacky way) perform the filter right before the groupby operation if you wanted.

# %%
# The count is the number of occurrences
ufo_vars.groupby(by='year')['encounter_length'].agg(['mean','count'])#The mean average of all encounter durations during the year
# Out:
#               mean  count
# year
# 1906  10800.000000      1
# 1910    120.000000      2
# 1916     60.000000      1
# 1920     60.000000      1
# 1925     60.000000      1
# ...            ...    ...
# 2010  21505.553280   4283
# 2011   2463.336332   5107
# 2012   9270.678520   7357
# 2013   4324.556170   7037
# 2014    854.096252   2260
#
# [87 rows x 2 columns]

# %% [markdown]
# # BONUS 2: Which months are the ones with the highest numbers of occurrences?

# %%
ufo_vars.groupby(by='month')['encounter_length'].agg(['mean','count','max']) # october and june
# Out:
#                mean  count         max
# month
# 1       4412.863560   5689   9468000.0
# 2       4758.293253   4664   6312000.0
# 3       7581.668545   5450  10526400.0
# 4      11519.743815   5526  52623200.0
# 5       2860.741330   5293   2631600.0
# 6      19012.226308   8152  82800000.0
# 7       1669.213670   9519   2631600.0
# 8      15660.454416   8636  52623200.0
# 9      10475.527612   7589  66276000.0
# 10     17254.464963   7407  97836000.0
# 11      1623.653784   6739   1209600.0
# 12      5747.952990   5665   6312000.0

# %% [markdown]
# # BONUS 3: Finally, you gathered information about the UFO dataset. Using your last result, try to bring that information for your original dataset.

# %% [markdown]
# 1. Store the results of your previous analysis (the mean value for the encounter_seconds for each year and each country) in a dataframe called `avg_results`.

# %%
avg_results = ufo_vars.groupby(by=['year','country'])['encounter_length'].agg(avg_sec='mean', count_ufo='count', max_ufo= 'max') 
avg_results
# Out:
#                   avg_sec  count_ufo   max_ufo
# year country
# 1910 us        120.000000          2     120.0
# 1920 us         60.000000          1      60.0
# 1925 us         60.000000          1      60.0
# 1929 us         60.000000          1      60.0
# 1931 us        930.000000          2    1800.0
# ...                   ...        ...       ...
# 2014 au       2197.214286         14   10800.0
#      ca        789.377778         45    3600.0
#      de       3720.000000          3   10800.0
#      gb       8366.761905         21  172800.0
#      us        782.372979       1964  172800.0
#
# [282 rows x 3 columns]

# %% [markdown]
# 2. Rename the column named `encounter_seconds` to `avg_encounter_seconds`.

# %%
avg_results.rename(columns={'encounter_length':'avg_encounter_seconds'}, inplace=True)
avg_results
# Out:
#                   avg_sec  count_ufo   max_ufo
# year country
# 1910 us        120.000000          2     120.0
# 1920 us         60.000000          1      60.0
# 1925 us         60.000000          1      60.0
# 1929 us         60.000000          1      60.0
# 1931 us        930.000000          2    1800.0
# ...                   ...        ...       ...
# 2014 au       2197.214286         14   10800.0
#      ca        789.377778         45    3600.0
#      de       3720.000000          3   10800.0
#      gb       8366.761905         21  172800.0
#      us        782.372979       1964  172800.0
#
# [282 rows x 3 columns]

# %% [markdown]
# 3. Use the pd.merge( ... ) function to bring that new collected information to your original dataset.
# The pd.merge() function requires several arguments, let's understand the most important ones.
#
# `left` is the dataframe you want to bring information **to** - the table on the left. In this case, this will be our original dataframe called `ufo`
#
# `right` is the dataframe you want to bring information **from** - the table on the right. In this case, this will be our resulting dataframe `avg_results`.
#
# `on` is the key you want to perform the merge. That is, if those values are **exactly equal** in both dataframes, then the information will be brought.
#
# Put your results on a dataframe called `merged_ufo`

# %%
merged_ufo = pd.merge(left=ufo, right=avg_results, left_on='encounter_length', right_on='avg_sec', how='left')
merged_ufo.sample(50)
# Out:
#               date  Unnamed: 0  year  month  day         date_time  \
# 56221   1995-12-15       18245  1995     12   15  12/15/1995 20:50
# 199386  2011-07-06       63228  2011      7    6    7/6/2011 18:45
# 124383  2006-04-03       40031  2006      4    3    4/3/2006 23:45
# 162214  2007-06-25       51744  2007      6   25   6/25/2007 03:30
# 142442  2008-05-05       45736  2008      5    5    5/5/2008 05:07
# 251077  2005-09-06       79572  2005      9    6    9/6/2005 05:30
# 57324   2011-12-16       18582  2011     12   16  12/16/2011 06:05
# 247279  2013-09-28       78346  2013      9   28   9/28/2013 21:30
# 158346  2012-06-20       50538  2012      6   20   6/20/2012 21:29
# 219063  2012-08-24       69355  2012      8   24   8/24/2012 20:40
# 44291   2000-11-04       14343  2000     11    4   11/4/2000 20:45
# 175948  2006-07-13       56010  2006      7   13   7/13/2006 01:00
# 215993  2006-08-21       68380  2006      8   21   8/21/2006 22:00
# 22993   2001-01-10        7451  2001      1   10   1/10/2001 05:13
# 194491  2004-07-04       61814  2004      7    4    7/4/2004 22:15
# 251652  2004-09-07       79753  2004      9    7    9/7/2004 04:15
# 87019   2001-02-22       28006  2001      2   22   2/22/2001 17:19
# 104258  2014-03-25       33539  2014      3   25   3/25/2014 06:00
# 5174    2008-10-14        1618  2008     10   14  10/14/2008 22:35
# 149289  2002-06-01       47795  2002      6    1    6/1/2002 09:50
# 235113  2010-09-14       74428  2010      9   14   9/14/2010 23:58
# 177605  1965-07-15       56509  1965      7   15   7/15/1965 14:00
# 237675  1993-09-17       75236  1993      9   17   9/17/1993 22:00
# 163436  2007-06-27       52119  2007      6   27   6/27/2007 22:00
# 213619  2013-08-18       67611  2013      8   18   8/18/2013 22:18
# 137352  1999-05-24       44097  1999      5   24   5/24/1999 11:00
# 232142  1999-09-01       73476  1999      9    1    9/1/1999 21:30
# 23350   2010-01-10        7571  2010      1   10   1/10/2010 19:00
# 114475  1992-04-15       36854  1992      4   15   4/15/1992 22:00
# 13524   2008-10-24        4320  2008     10   24  10/24/2008 22:00
# 117677  1998-04-20       37877  1998      4   20   4/20/1998 10:30
# 46247   2008-01-15       14983  2008      1   15   1/15/2008 22:00
# 72718   2013-01-27       23394  2013      1   27   1/27/2013 21:00
# 120478  2001-04-24       38795  2001      4   24   4/24/2001 18:25
# 50208   2012-11-08       16245  2012     11    8   11/8/2012 21:30
# 84959   1999-02-19       27313  1999      2   19   2/19/1999 21:20
# 190754  2009-07-29       60640  2009      7   29   7/29/2009 22:35
# 90390   2008-02-29       29094  2008      2   29   2/29/2008 23:00
# 183364  2002-07-20       58313  2002      7   20   7/20/2002 21:40
# 68076   2002-01-23       21898  2002      1   23   1/23/2002 19:10
# 166516  2005-06-30       53086  2005      6   30   6/30/2005 23:25
# 93113   2009-02-08       29943  2009      2    8    2/8/2009 10:00
# 209341  1981-08-15       66296  1981      8   15   8/15/1981 21:00
# 123276  2005-04-29       39671  2005      4   29   4/29/2005 21:00
# 146067  2013-06-11       46853  2013      6   11   6/11/2013 22:15
# 77630   1982-01-07       24992  1982      1    7    1/7/1982 13:00
# 118512  2007-04-21       38155  2007      4   21   4/21/2007 23:00
# 140458  2011-05-30       45111  2011      5   30   5/30/2011 04:30
# 107749  2006-03-04       34666  2006      3    4    3/4/2006 11:15
# 92549   2007-02-07       29767  2007      2    7    2/7/2007 10:00
#
#                                                 city_area state country  \
# 56221                                          hawesville    ky      us
# 199386                                       doha (qatar)    al     NaN
# 124383                                 cardiff (uk/wales)   NaN      gb
# 162214                                             marion    mi      us
# 142442                                             calais    vt     NaN
# 251077                                           columbia    pa      us
# 57324                                            hopewell    va      us
# 247279                                       chesterfield    va      us
# 158346                                 millinocket (near)    me      us
# 219063                                           pasadena    md      us
# 44291                                          scottsdale    az      us
# 175948                                            hancock    wi      us
# 215993                                          charlotte    mi      us
# 22993                                               arden    nc      us
# 194491                                          arlington    ma      us
# 251652                                              depew    ny      us
# 87019                              murdock/port charlotte    fl     NaN
# 104258                                   halifax (canada)    ns      ca
# 5174                                              manteca    ca      us
# 149289                               newport (uk/england)   NaN      gb
# 235113                                        fort gaines    ga      us
# 177605                                        san gabriel    tx      us
# 237675                                  red deer (canada)    ab      ca
# 163436                                           oak lawn    il      us
# 213619                                         trout lake    wa      us
# 137352                                           glendale    az      us
# 232142  lake trinity (aprox. 30 miles north of redding...    ca     NaN
# 23350                                              eunice    la      us
# 114475                                             neosho    mo      us
# 13524                                   edmonton (canada)    ab      ca
# 117677                                valdosta (south of)    ga      us
# 46247                                        spring creek    nv      us
# 72718                                               kelso    wa      us
# 120478                                       hillsborough    nc      us
# 50208                                          whiteville    nc      us
# 84959                                         simi valley    ca      us
# 190754                                             euless    tx      us
# 90390                          minneapolis (near; hwy 81)    ks      us
# 183364                                          ford city    pa      us
# 68076                                             banning    ca      us
# 166516                                            jackson    pa      us
# 93113                                              duluth    mn      us
# 209341                                              vichy    mo      us
# 123276                                         chelmsford    ma      us
# 146067                                   colorado springs    co      us
# 77630                                 london (uk/england)   NaN      gb
# 118512                                    cancun (mexico)   NaN     NaN
# 140458                             eleven mile state park    co     NaN
# 107749                                       laguna beach    ca      us
# 92549                                          charleston    sc      us
#
#         ufo_shape  encounter_length described_encounter_length  \
# 56221    changing             300.0        less than 5 minutes
# 199386     sphere             300.0                  5 minutes
# 124383      other              30.0                  20-30secs
# 162214      light             900.0            15 minutes plus
# 142442      light             120.0                  2 minutes
# 251077       disk              30.0                 30 seconds
# 57324    triangle             120.0                      2 min
# 247279      light             300.0                  5 minutes
# 158346     circle             180.0                2-3 minutes
# 219063   fireball             600.0                10  minutes
# 44291    triangle              60.0                   1 minute
# 175948      cigar             240.0                      4 min
# 215993      light              60.0                   1 minute
# 22993       cigar              30.0                    30 secs
# 194491     circle              30.0                 30 seconds
# 251652       disk            1200.0                 20 minutes
# 87019       other             180.0               :02-:03 min.
# 104258     circle            1800.0                 30 minutes
# 5174       circle             300.0                   ~ 5 min.
# 149289   teardrop             300.0                     5 mins
# 235113   fireball             300.0                     5 mins
# 177605       oval            1800.0                 30 minutes
# 237675      other             120.0               1- 2 minutes
# 163436      light               6.0                  6 seconds
# 213619      light              60.0              30-60 seconds
# 137352       disk             180.0                     3 min.
# 232142   fireball             120.0               aprox 2 min.
# 23350        oval             900.0                 15:00 mins
# 114475    unknown              60.0                 one minute
# 13524       light             900.0                 15 minutes
# 117677     circle              30.0                 30 seconds
# 46247   formation             120.0                  2 minutes
# 72718       other             120.0                 ~2 minutes
# 120478      other              60.0                    60secs.
# 50208    fireball               5.0                  5 seconds
# 84959       other             120.0                  2 minutes
# 190754      light               5.0                  5 seconds
# 90390    triangle             120.0                     2 min.
# 183364    unknown              60.0                   1 minute
# 68076     chevron             600.0           about 10 minutes
# 166516   fireball              30.0                     30 sec
# 93113    triangle             180.0                  3 minutes
# 209341    unknown             180.0                   1-3 min.
# 123276     sphere              60.0                   1 minute
# 146067    unknown               3.0                  3 seconds
# 77630      sphere             900.0                     15mins
# 118512    unknown              30.0                 30 seconds
# 140458      light             300.0                      5 min
# 107749     circle             120.0                  2 minutes
# 92549       light              60.0                   1 minute
#
#                                               description date_documented  \
# 56221   Strange orange light/craft hovering noiselessl...       7/16/2006
# 199386  Round object emitting steady white light seen ...       7/17/2011
# 124383  They sped off in a Northly direction. These we...       5/15/2006
# 162214  Two lights in the sky at the same height; one ...        8/7/2007
# 142442  Moving bright white light moving north to sout...       6/12/2008
# 251077  9/6/05 05:30 AM Columbia&#44 PA  30 second dur...       7/16/2006
# 57324           Triangle UFO spotted in Hopewell Virginia       1/12/2012
# 247279  Four orange objects flying in a semi formation...       9/30/2013
# 158346                                         Cool light        7/4/2012
# 219063  Two red flare looking objects floated up in th...       9/24/2012
# 44291   The back of our home looks south over Scottsda...       12/2/2000
# 175948                               shining bright light      10/30/2006
# 215993  two balls of light&#44 the second was only 40 ...      10/30/2006
# 22993   High SPeed Cigar Shaped Object - Sky Turning  ...       9/24/2003
# 194491                                  Fast moving light        7/8/2004
# 251652  Bright white light with smaller lights circlin...        9/9/2004
# 87019     Possible exotic new stealth aircraft witnessed.       2/24/2001
# 104258                   Moving stars and V-shaped craft.       3/27/2014
# 5174    ~10:35 PM&#44 Central Valley California. 10/14...      10/31/2008
# 149289  large object&#44 ballon or parachute shaped ap...       6/12/2002
# 235113                                 bright orange ball      11/21/2010
# 177605  High in the daylight sky&#44 a stationary oval...        9/9/2004
# 237675  Strange shaped object&#44 no sound&#44 no ligh...       6/18/2004
# 163436  Green light moving toward 103rd st from 95th &...        8/7/2007
# 213619  UFO light ship with power up cruising over our...       8/30/2013
# 137352  We saw a silver disc not moving at all at abou...       6/23/1999
# 232142  Witnessed a bright red ball of light floating ...       9/12/1999
# 23350   Two objects meet then leave each other one to ...       2/14/2010
# 114475  I don&#39t remember for sure when this happene...      11/28/2007
# 13524              Balls of lights dancing in the clouds.      10/31/2008
# 117677  I think this was an Alien craft because it had...        8/5/2001
# 46247   light becomes bright then turns into group of ...        3/4/2008
# 72718         Strange humanoid encounter. No crafts seen.       2/18/2013
# 120478  Large plane with triangle wings in rear with l...       4/28/2001
# 50208   I was driving down a rural Highway 701S leavin...      11/19/2012
# 84959   Large amber shape spotted in the Northwest sky...        4/2/1999
# 190754  space based bright light that moves&#44 then f...        8/5/2009
# 90390   triangular craft with white lights at each poi...       4/17/2008
# 183364  Three steady&#44 red lights were observed at t...       7/26/2002
# 68076   A structure of lights&#44 resembling the Phoen...       1/29/2002
# 166516  ((HOAX??))  Looked like it was a red moon comi...      11/28/2007
# 93113   ((HOAX??))  black triangle&#44 three white lig...       4/13/2010
# 209341  8/15/1981&#44 9:00pm&#44 vibrating/humming/rev...       3/19/2009
# 123276  ((NUFORC Note:  Missile launch at 2055 hrs (ED...       5/11/2005
# 146067     Fast moving ufo with orange and white circles.        7/3/2013
# 77630   SPHERICAL UFO sighted 20 METERS away IN BROAD ...       7/16/2003
# 118512  Star like object on northerly course makes 120...       4/27/2007
# 140458  Two bright white lights with a translucent vei...        6/3/2011
# 107749  I was looking up at a large hole in a large cl...       3/11/2006
# 92549   UNEXPLAINED SIGHTING OF A POSSIBLE UFO  @ CHAR...        3/4/2008
#
#          latitude   longitude  avg_sec  count_ufo  max_ufo
# 56221   37.900000  -86.755000    300.0        1.0    300.0
# 199386  30.593498   31.498372    300.0        2.0    300.0
# 124383  51.500000   -3.200000     30.0        1.0     30.0
# 162214  44.102500  -85.146944    900.0        1.0    900.0
# 142442  44.363296  -72.466343    120.0        2.0    180.0
# 251077  40.033611  -76.504722     30.0        1.0     30.0
# 57324   37.304167  -77.287500    120.0        2.0    180.0
# 247279  37.376944  -77.506111    300.0        2.0    300.0
# 158346  45.657222  -68.710278    180.0        1.0    180.0
# 219063  39.107222  -76.571389    600.0        1.0    600.0
# 44291   33.509167 -111.898333     60.0        1.0     60.0
# 175948  44.133611  -89.523056    240.0        2.0    300.0
# 215993  42.563611  -84.835833     60.0        1.0     60.0
# 22993   35.466111  -82.516667     30.0        1.0     30.0
# 194491  42.415278  -71.156944     30.0        1.0     30.0
# 251652  42.903889  -78.692500   1200.0        1.0   1200.0
# 87019   27.006711  -82.147212    180.0        1.0    180.0
# 104258  44.650000  -63.600000   1800.0        1.0   1800.0
# 5174    37.797500 -121.215000    300.0        1.0    300.0
# 149289  52.016667   -4.833333    300.0        1.0    300.0
# 235113  31.608889  -85.047222    300.0        1.0    300.0
# 177605  30.694167  -97.195833   1800.0        1.0   1800.0
# 237675  52.266667 -113.800000    120.0        2.0    180.0
# 163436  41.710833  -87.758056      6.0        1.0      6.0
# 213619  45.997500 -121.526944     60.0        1.0     60.0
# 137352  33.538611 -112.185278    180.0        1.0    180.0
# 232142  40.981833 -123.011598    120.0        1.0    120.0
# 23350   30.494167  -92.417500    900.0        1.0    900.0
# 114475  36.868889  -94.367778     60.0        1.0     60.0
# 13524   53.550000 -113.500000    900.0        1.0    900.0
# 117677  30.832500  -83.278611     30.0        1.0     30.0
# 46247   40.726667 -115.585000    120.0        1.0    120.0
# 72718   46.146944 -122.907222    120.0        1.0    120.0
# 120478  36.075278  -79.100000     60.0        1.0     60.0
# 50208   34.338611  -78.703333      5.0        1.0      5.0
# 84959   34.269444 -118.780556    120.0        2.0    120.0
# 190754  32.836944  -97.081667      5.0        1.0      5.0
# 90390   39.121944  -97.706389    120.0        1.0    120.0
# 183364  40.772222  -79.530000     60.0        1.0     60.0
# 68076   33.925556 -116.875556    600.0        1.0    600.0
# 166516  41.838056  -75.591111     30.0        1.0     30.0
# 93113   46.783333  -92.106389    180.0        1.0    180.0
# 209341  38.111389  -91.760278    180.0        1.0    180.0
# 123276  42.599722  -71.367778     60.0        1.0     60.0
# 146067  38.833889 -104.820833      3.0        1.0      3.0
# 77630   51.514125   -0.093689    900.0        1.0    900.0
# 118512  21.161908  -86.851528     30.0        1.0     30.0
# 140458  38.948849 -105.527270    300.0        1.0    300.0
# 107749  33.542222 -117.782222    120.0        2.0    180.0
# 92549   32.776389  -79.931111     60.0        1.0     60.0

# %% [markdown]
# Check how many rows the final result has and try to explain it. Did the dataset get smaller? Bigger? Or the same? Can you explain why?
#
# *hint: If you've found something weird, try looking back at your original dataframe and find something interesting on it.*

# %%
# Got bigger, it got more columns added to it, and it repeated encounter_length and avg_seconds

# %% [markdown]
# ## Store the results into a new csv file called `ufo_enriched.csv`.
#
# Don't forget to use `index=False`.

# %%
pwd
# Out:
# 'C:\\Users\\Alvaro Camacho\\Desktop\\Ironhack\\Week 2\\week2_day3'

# %%
merged_ufo.to_csv('C:\\Users\\Alvaro Camacho\\Desktop\\Ironhack\\Week 2\\week2_day3/ufo_enriched.csv', index=False)
